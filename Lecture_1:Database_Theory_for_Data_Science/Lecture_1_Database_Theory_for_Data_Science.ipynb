# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/SQL-for-Data-Science/blob/main/Lecture_1%3ADatabase_Theory_for_Data_Science/Lecture_1_Database_Theory_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **📘 Lecture 1: Database Theory for Data Science**
#
#
# ---
#
# A Database is a shared collection of logically related data and description of these data, designed to meet the information needs of an organization
#
# # **DBMS**
#
# A Database Management System is a software system that enables user to define, create ,maintain, and control access to the database.
#
# Database System typically have high cost and they require high end hardware configurations.
#
# An Application program interacts with a database by issuing an appropriate request (typically a SQL statement)

# %% [markdown]
# # **✅ Why Do We Need Databases in Data Science?**
#
#
# ---

# %% [markdown]
# # **In Data Science, we often deal with:**
#
# Large volumes of data
#
# Data from multiple sources
#
# Need for fast filtering, aggregations, and reporting
#
# Clean and structured storage
#
# While CSV/Excel files work for small-scale tasks,
#
# # **they break down when you:**
#
# Handle millions of rows
#
# Need to connect multiple datasets
#
# Want secure and fast queries

# %% [markdown]
# # **📂 Why Not Just Use Files (CSV, Excel)?**

# %% [markdown]
# ![limitation of flat files.png](data:image/png;base64,...)

# %% [markdown]
# ✅ Use Flat Files When:
# You have small datasets
#
# You're doing quick analysis
#
# You don't need to JOIN or filter deeply
#
# You’re sharing static reports

# %% [markdown]
# # **✅ When to Use Databases**
#
# **Use SQL databases when:**
#
# You work with relational data (data linked by keys)
#
# You need complex queries
#
# Data is updated frequently
#
# You need security, structure, and consistency
#
# You want to build a dashboard or app on top of your data

# %% [markdown]
# # **💼 Practical Use Cases for Files vs. Databases**

# %% [markdown]
# ![files vs databases.png](data:image/png;base64,...)

# %% [markdown]
# # **🧠 Concept: What Is a Database?**
#
#
# ---
#
#
#
# A database is a structured way of storing, retrieving, and managing data.
#
#
# It stores data in tables (like Excel sheets).
#
#
# Each table contains rows (records) and columns (fields).
#
#
# Tables can be linked using primary keys and foreign keys.

# %% [markdown]
# # **Why SQL Is Perfect for Data Science**
#
# SQL helps you clean, transform, and analyze data
#
# Great for filtering, grouping, aggregating
#
# Used in tools like Power BI, Tableau, Python (via Pandas/SQLAlchemy)

# %% [markdown]
# # **📚 Types of Databases**
#
#
# ---
#
#
#
# **1. Relational Databases (RDBMS) – Most Common for Data Science**
#
# Stores data in tables with rows and columns
#
# Uses SQL (Structured Query Language)
#
# Tables are linked by Primary Key and Foreign Key
#
# Enforces ACID properties (Atomicity, Consistency, Isolation, Durability)
#
# **✅ Examples:**
#
# PostgreSQL
#
# MySQL
#
# SQLite
#
# Microsoft SQL Server (microsoft access)
#
# Oracle data base management system

# %% [markdown]
# # 💡 SQL Table Example: Think of a Relational Database Like This
#
#
# ---

# %%
# -- Customer Table
# CREATE TABLE customers (
#     customer_id INTEGER PRIMARY KEY,
#     name TEXT,
#     email TEXT
# );

# -- Orders Table
# CREATE TABLE orders (
#     order_id INTEGER PRIMARY KEY,
#     customer_id INTEGER,
#     product TEXT,
#     amount INTEGER,
#     FOREIGN KEY (customer_id) REFERENCES customers(customer_id)
# );

# %% [markdown]
# # **2. NoSQL Databases – Schema-less and Scalable**
#
#
# ---
#
#
# Non-relational: designed for flexibility and scale
#
# Stores data as JSON, key-value, documents, or graphs
#
# No fixed schema → good for unstructured or semi-structured data
#
# ✅ Examples:
#
# MongoDB (Document DB)
#
# Redis (Key-Value store)
#
# Cassandra (Wide-column)
#
# Neo4j (Graph DB)

# %%
## Example
# {
#   "customer_id": 101,
#   "name": "Alice",
#   "orders": [
#     {"order_id": 1, "amount": 200},
#     {"order_id": 2, "amount": 150}
#   ]
# }

# %% [markdown]
# # **3. In-Memory Databases – Fast Access for Real-Time**
#
# Stores data in RAM → extremely fast
#
# Used for caching or quick access
#
# ✅ Examples:
#
# Redis
#
# Memcached

# %% [markdown]
# # **4. Time-Series Databases – Focused on Time-based Data**
#
# Optimized for timestamped data (metrics, logs, sensor data)
#
# # **✅ Examples:**
# InfluxDB
#
# TimescaleDB

# %% [markdown]
# # **Data Integrity and Constraints**
#
#
# ---
# Data integrity refers to maintaining and assuring the accuracy and consistency of data over its entire life -cycle.
#
# Database Systems ensure data integrity through constraints which are used to restrict data that can be entered or modified in the database. Database System offer three types of integrity constraints

# %% [markdown]
# ![types of data integrity.png](data:image/png;base64,...)
